# %% [markdown]
# ## Машинное обучение

# %% [markdown]
# *Для начала все категориальные признаки переведём в числовые с помощью One-hot encoding. Далее разобьём нашу выборку на тренировочную, валидационную и тестовую. Нормализуем данные с помощью RobustScaler, так как он менее чувствительный к выбросам. В качестве метрики напишем свою функцию RMSE. Для начала попробуем предсказывать цену с помощью линейной регрессии и проверим, не переобучилась ли она (обратим внимание на веса модели). Посмотрим, что произойдёт с моделью, если мы добавим L1-, L2-регуляризацию. Затем оценим результаты, применяя kNN и Random Forest*
