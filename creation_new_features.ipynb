# %% [markdown]
# ## Создание новых признаков

# %% [markdown]
# *Подгружаем нужные библиотеки*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *Подгружаем файл*

# %%
df = pd.read_csv("data\\auto_new.csv")
df.head(5)
# Out:
#       model auto  year of production   mileage exterior colour      tax  \
# 0  Mercedes-Benz                2022      50.0          чёрный  17775.0
# 1        Renault                2022    7922.0      коричневый   2900.0
# 2            BMW                2023      30.0           синий  79500.0
# 3        Renault                2013  294501.0         бежевый   2750.0
# 4        Renault                2017   39579.0         бежевый    984.0
#
#      transmission wheel drive number of owners  engine volume  engine power  \
# 0  автоматическая      полный       1 владелец            2.0         237.0
# 1    механическая      полный      2 владельца            1.6         117.0
# 2  автоматическая      полный       1 владелец            4.4         530.0
# 3    механическая    передний      2 владельца            1.5         110.0
# 4    механическая    передний       1 владелец            1.6          82.0
#
#    engine type fuel type  acceleration   MPG country of the car brand class  \
# 0   дизельный        ДТ            8.5   7.2                Германия     M
# 1  бензиновый     АИ-95           13.1   7.3                 Франция     B
# 2  бензиновый     АИ-95            4.7  12.9                Германия     F
# 3   дизельный        ДТ           11.1   4.1                 Франция     C
# 4  бензиновый     АИ-95           12.3   7.3                 Франция     B
#
#    top speed environmental class       price
# 0      214.0             Euro 6   29800000.0
# 1      174.0             Euro 5    2380000.0
# 2      250.0             Euro 6   21900000.0
# 3      190.0             Euro 5     670000.0
# 4      165.0             Euro 5    1075000.0

# %% [markdown]
# *Добавим признак, отображающий эффективность использования топлива, который будет вычисляться путем деления среднего расхода топлива на объем двигателя, - fuel utilization efficiency*

# %%
df["fuel utilization efficiency"] = df["MPG"] / df["engine volume"]

# %% [markdown]
# *Кроме того, будем отслеживать оптимальность нашего двигателя. Данный признак будет вычисляться путем умножения объема двигателя на мощность двигателя на время разгона до 100 км/ч - engine optimality*

# %%
df["engine optimality"] = df["engine volume"] * df["engine power"] * df["acceleration"]

# %% [markdown]
# *Также добавим интенсивность использования автомобиля с момента его выпуска, которая будет рассчитываться как отношение общего пробега к количеству лет использования автомобиля - intensity of use*

# %%
df["intensity of use"] = df["mileage"] / (2024 - df["year of production"] + 1)

# %%
df.head(5)
# Out:
#       model auto  year of production   mileage exterior colour      tax  \
# 0  Mercedes-Benz                2022      50.0          чёрный  17775.0
# 1        Renault                2022    7922.0      коричневый   2900.0
# 2            BMW                2023      30.0           синий  79500.0
# 3        Renault                2013  294501.0         бежевый   2750.0
# 4        Renault                2017   39579.0         бежевый    984.0
#
#      transmission wheel drive number of owners  engine volume  engine power  \
# 0  автоматическая      полный       1 владелец            2.0         237.0
# 1    механическая      полный      2 владельца            1.6         117.0
# 2  автоматическая      полный       1 владелец            4.4         530.0
# 3    механическая    передний      2 владельца            1.5         110.0
# 4    механическая    передний       1 владелец            1.6          82.0
#
#    ... acceleration   MPG  country of the car brand  class top speed  \
# 0  ...          8.5   7.2                 Германия      M      214.0
# 1  ...         13.1   7.3                  Франция      B      174.0
# 2  ...          4.7  12.9                 Германия      F      250.0
# 3  ...         11.1   4.1                  Франция      C      190.0
# 4  ...         12.3   7.3                  Франция      B      165.0
#
#   environmental class       price fuel utilization efficiency  \
# 0             Euro 6   29800000.0                    3.600000
# 1             Euro 5    2380000.0                    4.562500
# 2             Euro 6   21900000.0                    2.931818
# 3             Euro 5     670000.0                    2.733333
# 4             Euro 5    1075000.0                    4.562500
#
#    engine optimality  intensity of use
# 0            4029.00         16.666667
# 1            2452.32       2640.666667
# 2           10960.40         15.000000
# 3            1831.50      24541.750000
# 4            1613.76       4947.375000
#
# [5 rows x 22 columns]
